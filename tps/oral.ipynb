# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate as integr

# %% [markdown]
# ### <ins>Code 1: Resolution des equa diffs avec la méthode d'Euler</ins>
#
# Cheat sheet Numpy fournis avec ce qu'il faut pour compléter une code en utilisant numpy.
#
# GOOD LUCK!

# %%
# A COMPLETER ICI
T = 8
dt = ...
x0 = ...

def euler(x0 : float, T : float, dt : float):

    """
    input:
        x0 : Initial condition point
        T : Lenght of interval
        dt : step
    
    return :
        L : list of values of Differential Equation
    """
    pass

# %%
# A COMPLETER
solution_points = ...

plt.figure(figsize=(10, 4))
plt.grid()
plt.plot() # A COMPLETER
plt.title("Solution for different x0")
plt.show()

# %% [markdown]
# ### <ins>Code 2: Tracer PHI:</ins>
#
# Note: pour calculer une intégrale, vous pouvez utiliser la fonction *intergrate.quad()* fournie pas scipy.
#
# ```
# quad(func, a, b, args=(), full_output=0, epsabs=1.49e-08, epsrel=1.49e-08,
#      limit=50, points=None, weight=None, wvar=None, wopts=None,
#      maxp1=50, limlst=50, complex_func=False)
# ```
#
# **Compute a definite integral.**
# Integrate `func` from `a` to `b` (possibly infinite interval) using a technique from the Fortran library **QUADPACK**.

# %%
def phi(x, n):
    """
    Params:
        x : Function in Phi
        n : nth composite of the function
    Returns:
        L : List of values of Phi 
    
    """
    pass

# %%
# A COMPLETER  

plt.figure(figsize=(10, 4))
plt.grid()
plt.plot()
plt.title("plotting for different params")
plt.show()
